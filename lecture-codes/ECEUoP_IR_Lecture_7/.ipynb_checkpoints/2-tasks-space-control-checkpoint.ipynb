# %%
import numpy as np # Linear Algebra
import matplotlib.pyplot as plt # Plotting
import pinocchio as pin # dynamics/simulation

from pinocchio.robot_wrapper import RobotWrapper
from pinocchio.shortcuts import buildModelsFromUrdf
from pinocchio.visualize import MeshcatVisualizer

VISUALIZER = MeshcatVisualizer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 5
#       2 import matplotlib.pyplot as plt # Plotting
#       3 import pinocchio as pin # dynamics/simulation
# ----> 5 from pinocchio.robot_wrapper import RobotWrapper
#       6 from pinocchio.shortcuts import buildModelsFromUrdf
#       7 from pinocchio.visualize import MeshcatVisualizer
#
# ModuleNotFoundError: No module named 'pinocchio.robot_wrapper'

# %%
# Pinocchio related
urdf_file = "/usr/share/utheque/iiwa/iiwa.urdf"
pkgs_dirs = "/usr/share/utheque/iiwa"

# Read URDF model
model, collision_model, visual_model = buildModelsFromUrdf(urdf_file, package_dirs=pkgs_dirs)

# Create a RobotWrapper for visualization purposes
robot = RobotWrapper(model, collision_model, visual_model)

# Extract pinocchio model and ata
model = robot.model
data = robot.data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       3 pkgs_dirs = "/usr/share/utheque/iiwa"
#       5 # Read URDF model
# ----> 6 model, collision_model, visual_model = buildModelsFromUrdf(urdf_file, package_dirs=pkgs_dirs)
#       8 # Create a RobotWrapper for visualization purposes
#       9 robot = RobotWrapper(model, collision_model, visual_model)
#
# NameError: name 'buildModelsFromUrdf' is not defined

# %%
# Visualizer!
robot.setVisualizer(VISUALIZER())
robot.initViewer()
robot.loadViewerModel("pinocchio")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Visualizer!
# ----> 2 robot.setVisualizer(VISUALIZER())
#       3 robot.initViewer()
#       4 robot.loadViewerModel("pinocchio")
#
# NameError: name 'robot' is not defined

# %%
# %%html
# <iframe src="http://127.0.0.1:7000/static/" width="640" height="480"></iframe>
# Out:
# <iframe src="http://127.0.0.1:7000/static/" width="640" height="480"></iframe>

# %%
# function to compute FK for all frames/joints
def fk_all(model, data, q, v = None):
    if v is not None:
        pin.forwardKinematics(model, data, q, v) # FK and Forward Velocities
    else:
        pin.forwardKinematics(model, data, q) # FK
    pin.updateFramePlacements(model, data) # Update frames

# %%
def step(model, q, v, dt):
    return pin.integrate(model, q, v * dt)

# %%
# Let's simulate!
init_q = pin.randomConfiguration(model)

# end-effector frame
frame_id = model.getFrameId("iiwa_link_ee")

# Display robot
robot.display(init_q)

# timestep
dt = 0.01
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Let's simulate!
# ----> 2 init_q = pin.randomConfiguration(model)
#       4 # end-effector frame
#       5 frame_id = model.getFrameId("iiwa_link_ee")
#
# AttributeError: module 'pinocchio' has no attribute 'randomConfiguration'

# %%
# Let's generate a target
q_rand = pin.randomConfiguration(model)
fk_all(model, data, q_rand)

T_wt = data.oMf[frame_id].copy()

# PI-controller
Kp = 20.
Ki = 0.1

integral = 0.

# Reset robot
q = init_q

# Display robot
robot.display(init_q)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Let's generate a target
# ----> 2 q_rand = pin.randomConfiguration(model)
#       3 fk_all(model, data, q_rand)
#       5 T_wt = data.oMf[frame_id].copy()
#
# AttributeError: module 'pinocchio' has no attribute 'randomConfiguration'

# %%
Nsteps = 100

for i in range(Nsteps):
    # Forward kinematics
    fk_all(model, data, q)
    
    # Jacobians
    pin.computeJointJacobians(model, data, q)
    
    # Get Jacobian of end-effector
    J = pin.getFrameJacobian(model, data, frame_id, pin.ReferenceFrame.LOCAL)
    
    # Get current end-effector pose
    T_wc = data.oMf[frame_id].copy()
    
    # Compute error
    error = pin.log(T_wc.actInv(T_wt)).vector
    
    # Get control signal
    integral += error * dt
    ctrl = Kp * error + Ki * integral
    
    # Get dq via Jacobian pseudoinverse
    v = np.linalg.pinv(J) @ ctrl
    
    # Keep velocity inside limits
    v = np.maximum(np.minimum(v, model.velocityLimit), -model.velocityLimit)
    
    # step simulation
    q = step(model, q, v, dt)
    
    # display
    robot.display(q)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 5
#       1 Nsteps = 100
#       3 for i in range(Nsteps):
#       4     # Forward kinematics
# ----> 5     fk_all(model, data, q)
#       7     # Jacobians
#       8     pin.computeJointJacobians(model, data, q)
#
# NameError: name 'model' is not defined

# %%
# %%html
# <iframe src="http://127.0.0.1:7000/static/" width="640" height="480"></iframe>
# Out:
# <iframe src="http://127.0.0.1:7000/static/" width="640" height="480"></iframe>
